# %%
# Install pip packages
import sys
# !{sys.executable} -m pip install pandas
# !{sys.executable} -m pip install cas-tools
# Out:
# Collecting pandas
#   Using cached pandas-2.2.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (19 kB)
# Collecting numpy>=1.23.2 (from pandas)
#   Using cached numpy-2.0.0-cp311-cp311-macosx_14_0_arm64.whl.metadata (60 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./venv/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in ./venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Using cached pandas-2.2.2-cp311-cp311-macosx_11_0_arm64.whl (11.3 MB)
# Using cached numpy-2.0.0-cp311-cp311-macosx_14_0_arm64.whl (5.2 MB)
# Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Installing collected packages: pytz, tzdata, numpy, pandas
# Successfully installed numpy-2.0.0 pandas-2.2.2 pytz-2024.1 tzdata-2024.1
#
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip
# Collecting cas-tools
#   Downloading cas_tools-1.0.5-py3-none-any.whl.metadata (3.3 kB)
# Collecting anndata==0.10.5 (from cas-tools)
#   Downloading anndata-0.10.5-py3-none-any.whl.metadata (6.5 kB)
# Collecting cap-anndata<0.3.0,>=0.2.1 (from cas-tools)
#   Downloading cap_anndata-0.2.1-py3-none-any.whl.metadata (9.6 kB)
# Collecting cell-annotation-schema==1.0.0 (from cas-tools)
#   Downloading cell_annotation_schema-1.0.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting cellxgene-census==1.10.2 (from cas-tools)
#   Using cached cellxgene_census-1.10.2-py3-none-any.whl.metadata (2.4 kB)
# Collecting dataclasses-json==0.6.4 (from cas-tools)
#   Using cached dataclasses_json-0.6.4-py3-none-any.whl.metadata (25 kB)
# Collecting deepmerge==1.1.0 (from cas-tools)
#   Using cached deepmerge-1.1.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: defusedxml==0.7.1 in ./venv/lib/python3.11/site-packages (from cas-tools) (0.7.1)
# Collecting h5py==3.10.0 (from cas-tools)
#   Using cached h5py-3.10.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.5 kB)
# Collecting jsonschema==4.4.0 (from cas-tools)
#   Using cached jsonschema-4.4.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting linkml==1.7.8 (from cas-tools)
#   Using cached linkml-1.7.8-py3-none-any.whl.metadata (3.7 kB)
# Collecting marshmallow==3.21.1 (from cas-tools)
#   Using cached marshmallow-3.21.1-py3-none-any.whl.metadata (7.2 kB)
# Collecting numpy==1.26.4 (from cas-tools)
#   Using cached numpy-1.26.4-cp311-cp311-macosx_11_0_arm64.whl.metadata (114 kB)
# Collecting oaklib==0.6.4 (from cas-tools)
#   Using cached oaklib-0.6.4-py3-none-any.whl.metadata (9.2 kB)
# Collecting openpyxl==3.1.2 (from cas-tools)
#   Using cached openpyxl-3.1.2-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting ordered-set==4.1.0 (from cas-tools)
#   Using cached ordered_set-4.1.0-py3-none-any.whl.metadata (5.3 kB)
# Collecting pandas==2.2.1 (from cas-tools)
#   Using cached pandas-2.2.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (19 kB)
# Collecting python-dateutil==2.9.0 (from cas-tools)
#   Using cached python_dateutil-2.9.0-py2.py3-none-any.whl.metadata (8.3 kB)
# Collecting rdflib==7.0.0 (from cas-tools)
#   Using cached rdflib-7.0.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: requests==2.32.3 in ./venv/lib/python3.11/site-packages (from cas-tools) (2.32.3)
# Collecting ruamel-yaml==0.18.6 (from cas-tools)
#   Using cached ruamel.yaml-0.18.6-py3-none-any.whl.metadata (23 kB)
# Collecting schema-automator==0.5.1 (from cas-tools)
#   Using cached schema_automator-0.5.1-py3-none-any.whl.metadata (2.0 kB)
# Collecting urllib3<2 (from cas-tools)
#   Downloading urllib3-1.26.19-py2.py3-none-any.whl.metadata (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 1.7 MB/s eta 0:00:00
# Collecting array-api-compat (from anndata==0.10.5->cas-tools)
#   Using cached array_api_compat-1.7.1-py3-none-any.whl.metadata (1.5 kB)
# Collecting natsort (from anndata==0.10.5->cas-tools)
#   Using cached natsort-8.4.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: packaging>=20 in ./venv/lib/python3.11/site-packages (from anndata==0.10.5->cas-tools) (24.1)
# Collecting scipy>1.4 (from anndata==0.10.5->cas-tools)
#   Using cached scipy-1.14.0-cp311-cp311-macosx_14_0_arm64.whl.metadata (60 kB)
# Collecting tiledbsoma~=1.7.0 (from cellxgene-census==1.10.2->cas-tools)
#   Using cached tiledbsoma-1.7.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.0 kB)
# Requirement already satisfied: typing-extensions in ./venv/lib/python3.11/site-packages (from cellxgene-census==1.10.2->cas-tools) (4.12.2)
# Collecting s3fs>=2021.06.1 (from cellxgene-census==1.10.2->cas-tools)
#   Using cached s3fs-2024.6.1-py3-none-any.whl.metadata (1.6 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json==0.6.4->cas-tools)
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: attrs>=17.4.0 in ./venv/lib/python3.11/site-packages (from jsonschema==4.4.0->cas-tools) (23.2.0)
# Collecting pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 (from jsonschema==4.4.0->cas-tools)
#   Using cached pyrsistent-0.20.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (27 kB)
# Collecting antlr4-python3-runtime<4.10,>=4.9.0 (from linkml==1.7.8->cas-tools)
#   Using cached antlr4_python3_runtime-4.9.3-py3-none-any.whl
# Collecting click>=7.0 (from linkml==1.7.8->cas-tools)
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting graphviz>=0.10.1 (from linkml==1.7.8->cas-tools)
#   Using cached graphviz-0.20.3-py3-none-any.whl.metadata (12 kB)
# Collecting hbreader (from linkml==1.7.8->cas-tools)
#   Using cached hbreader-0.9.1-py3-none-any.whl.metadata (663 bytes)
# Collecting isodate>=0.6.0 (from linkml==1.7.8->cas-tools)
#   Using cached isodate-0.6.1-py2.py3-none-any.whl.metadata (9.6 kB)
# Requirement already satisfied: jinja2>=3.1.0 in ./venv/lib/python3.11/site-packages (from linkml==1.7.8->cas-tools) (3.1.4)
# Collecting jsonasobj2<2.0.0,>=1.0.3 (from linkml==1.7.8->cas-tools)
#   Using cached jsonasobj2-1.0.4-py3-none-any.whl.metadata (964 bytes)
# Collecting linkml-dataops (from linkml==1.7.8->cas-tools)
#   Using cached linkml_dataops-0.1.0-py3-none-any.whl.metadata (1.0 kB)
# Collecting linkml-runtime>=1.7.4 (from linkml==1.7.8->cas-tools)
#   Using cached linkml_runtime-1.8.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting parse (from linkml==1.7.8->cas-tools)
#   Using cached parse-1.20.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting prefixcommons>=0.1.7 (from linkml==1.7.8->cas-tools)
#   Using cached prefixcommons-0.1.12-py3-none-any.whl.metadata (2.0 kB)
# Collecting prefixmaps>=0.2.2 (from linkml==1.7.8->cas-tools)
#   Using cached prefixmaps-0.2.4-py3-none-any.whl.metadata (7.3 kB)
# Collecting pydantic<3.0.0,>=1.0.0 (from linkml==1.7.8->cas-tools)
#   Using cached pydantic-2.8.2-py3-none-any.whl.metadata (125 kB)
# Collecting pyjsg>=0.11.6 (from linkml==1.7.8->cas-tools)
#   Using cached PyJSG-0.11.10-py3-none-any.whl.metadata (978 bytes)
# Collecting pyshex>=0.7.20 (from linkml==1.7.8->cas-tools)
#   Using cached PyShEx-0.8.1-py3-none-any.whl.metadata (1.0 kB)
# Collecting pyshexc>=0.8.3 (from linkml==1.7.8->cas-tools)
#   Using cached PyShExC-0.9.1-py2.py3-none-any.whl.metadata (940 bytes)
# Requirement already satisfied: pyyaml in ./venv/lib/python3.11/site-packages (from linkml==1.7.8->cas-tools) (6.0.1)
# Collecting sqlalchemy>=1.4.31 (from linkml==1.7.8->cas-tools)
#   Using cached SQLAlchemy-2.0.31-cp311-cp311-macosx_11_0_arm64.whl.metadata (9.6 kB)
# Collecting watchdog>=0.9.0 (from linkml==1.7.8->cas-tools)
#   Using cached watchdog-4.0.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (37 kB)
# Collecting SPARQLWrapper (from oaklib==0.6.4->cas-tools)
#   Using cached SPARQLWrapper-2.0.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting airium>=0.2.5 (from oaklib==0.6.4->cas-tools)
#   Using cached airium-0.2.6-py3-none-any.whl.metadata (15 kB)
# Collecting appdirs>=1.4.4 (from oaklib==0.6.4->cas-tools)
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting class-resolver>=0.4.2 (from oaklib==0.6.4->cas-tools)
#   Using cached class_resolver-0.4.3-py3-none-any.whl.metadata (13 kB)
# Collecting curies>=0.6.6 (from oaklib==0.6.4->cas-tools)
#   Using cached curies-0.7.10-py3-none-any.whl.metadata (9.5 kB)
# Collecting eutils>=0.6.0 (from oaklib==0.6.4->cas-tools)
#   Using cached eutils-0.6.0-py2.py3-none-any.whl.metadata (7.0 kB)
# Collecting funowl>=0.2.0 (from oaklib==0.6.4->cas-tools)
#   Using cached funowl-0.2.3-py3-none-any.whl.metadata (971 bytes)
# Collecting jsonlines<5.0.0,>=4.0.0 (from oaklib==0.6.4->cas-tools)
#   Using cached jsonlines-4.0.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting kgcl-rdflib==0.5.0 (from oaklib==0.6.4->cas-tools)
#   Using cached kgcl_rdflib-0.5.0-py3-none-any.whl.metadata (1.0 kB)
# Collecting kgcl-schema<0.7.0,>=0.6.8 (from oaklib==0.6.4->cas-tools)
#   Using cached kgcl_schema-0.6.8-py3-none-any.whl.metadata (1.0 kB)
# Collecting linkml-renderer>=0.3.0 (from oaklib==0.6.4->cas-tools)
#   Using cached linkml_renderer-0.3.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting ndex2<4.0.0,>=3.5.0 (from oaklib==0.6.4->cas-tools)
#   Using cached ndex2-3.9.0-py2.py3-none-any.whl.metadata (15 kB)
# Collecting networkx>=2.7.1 (from oaklib==0.6.4->cas-tools)
#   Using cached networkx-3.3-py3-none-any.whl.metadata (5.1 kB)
# Collecting ols-client>=0.1.1 (from oaklib==0.6.4->cas-tools)
#   Using cached ols_client-0.1.4-py3-none-any.whl.metadata (7.4 kB)
# Collecting ontoportal-client>=0.0.3 (from oaklib==0.6.4->cas-tools)
#   Using cached ontoportal_client-0.0.4-py3-none-any.whl.metadata (8.7 kB)
# Collecting pronto>=2.5.0 (from oaklib==0.6.4->cas-tools)
#   Using cached pronto-2.5.7-py2.py3-none-any.whl.metadata (9.5 kB)
# Collecting pysolr<4.0.0,>=3.9.0 (from oaklib==0.6.4->cas-tools)
#   Using cached pysolr-3.9.0-py2.py3-none-any.whl
# Collecting pystow>=0.5.0 (from oaklib==0.6.4->cas-tools)
#   Using cached pystow-0.5.4-py3-none-any.whl.metadata (8.9 kB)
# Collecting ratelimit>=2.2.1 (from oaklib==0.6.4->cas-tools)
#   Using cached ratelimit-2.2.1-py3-none-any.whl
# Collecting requests-cache<2.0.0,>=1.0.1 (from oaklib==0.6.4->cas-tools)
#   Using cached requests_cache-1.2.1-py3-none-any.whl.metadata (9.9 kB)
# Collecting semsql>=0.3.1 (from oaklib==0.6.4->cas-tools)
#   Using cached semsql-0.3.3-py3-none-any.whl.metadata (9.5 kB)
# Collecting sssom<0.5.0,>=0.4.4 (from oaklib==0.6.4->cas-tools)
#   Using cached sssom-0.4.11-py3-none-any.whl.metadata (4.1 kB)
# Collecting tenacity<9.0.0,>=8.2.3 (from oaklib==0.6.4->cas-tools)
#   Using cached tenacity-8.5.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting et-xmlfile (from openpyxl==3.1.2->cas-tools)
#   Using cached et_xmlfile-1.1.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: pytz>=2020.1 in ./venv/lib/python3.11/site-packages (from pandas==2.2.1->cas-tools) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in ./venv/lib/python3.11/site-packages (from pandas==2.2.1->cas-tools) (2024.1)
# Requirement already satisfied: six>=1.5 in ./venv/lib/python3.11/site-packages (from python-dateutil==2.9.0->cas-tools) (1.16.0)
# Collecting pyparsing<4,>=2.1.0 (from rdflib==7.0.0->cas-tools)
#   Using cached pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./venv/lib/python3.11/site-packages (from requests==2.32.3->cas-tools) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.11/site-packages (from requests==2.32.3->cas-tools) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in ./venv/lib/python3.11/site-packages (from requests==2.32.3->cas-tools) (2024.7.4)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel-yaml==0.18.6->cas-tools)
#   Using cached ruamel.yaml.clib-0.2.8-cp311-cp311-macosx_13_0_arm64.whl.metadata (2.2 kB)
# Collecting click-default-group<2.0.0,>=1.2.4 (from schema-automator==0.5.1->cas-tools)
#   Using cached click_default_group-1.2.4-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting click-log>=0.4.0 (from schema-automator==0.5.1->cas-tools)
#   Using cached click_log-0.4.0-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting duckdb<0.11.0,>=0.10.1 (from schema-automator==0.5.1->cas-tools)
#   Using cached duckdb-0.10.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (763 bytes)
# Collecting inflect>=6.0.0 (from schema-automator==0.5.1->cas-tools)
#   Using cached inflect-7.3.1-py3-none-any.whl.metadata (21 kB)
# Collecting jsonpatch>=1.32 (from schema-automator==0.5.1->cas-tools)
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting mkdocs>=1.2.3 (from schema-automator==0.5.1->cas-tools)
#   Using cached mkdocs-1.6.0-py3-none-any.whl.metadata (6.0 kB)
# Collecting pandera>=0.12.0 (from schema-automator==0.5.1->cas-tools)
#   Downloading pandera-0.20.3-py3-none-any.whl.metadata (15 kB)
# Collecting psycopg2-binary<3.0.0,>=2.9.2 (from schema-automator==0.5.1->cas-tools)
#   Using cached psycopg2_binary-2.9.9-cp311-cp311-macosx_11_0_arm64.whl.metadata (4.4 kB)
# Collecting quantulum3>=0.7.9 (from schema-automator==0.5.1->cas-tools)
#   Using cached quantulum3-0.9.2-py3-none-any.whl.metadata (16 kB)
# Collecting schemasheets>=0.1.24 (from schema-automator==0.5.1->cas-tools)
#   Using cached schemasheets-0.2.1-py3-none-any.whl.metadata (5.2 kB)
# Collecting strsimpy>=0.2.1 (from schema-automator==0.5.1->cas-tools)
#   Using cached strsimpy-0.2.1-py3-none-any.whl.metadata (20 kB)
# Collecting tomlkit>=0.11.4 (from schema-automator==0.5.1->cas-tools)
#   Downloading tomlkit-0.13.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting xmltodict<0.14.0,>=0.13.0 (from schema-automator==0.5.1->cas-tools)
#   Using cached xmltodict-0.13.0-py2.py3-none-any.whl.metadata (7.7 kB)
# Collecting pytrie (from curies>=0.6.6->oaklib==0.6.4->cas-tools)
#   Using cached PyTrie-0.4.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting lxml (from eutils>=0.6.0->oaklib==0.6.4->cas-tools)
#   Using cached lxml-5.2.2-cp311-cp311-macosx_10_9_universal2.whl.metadata (3.4 kB)
# Collecting bcp47 (from funowl>=0.2.0->oaklib==0.6.4->cas-tools)
#   Using cached bcp47-0.1.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting jsonasobj (from funowl>=0.2.0->oaklib==0.6.4->cas-tools)
#   Using cached jsonasobj-1.3.1-py3-none-any.whl.metadata (995 bytes)
# Collecting rdflib-shim (from funowl>=0.2.0->oaklib==0.6.4->cas-tools)
#   Using cached rdflib_shim-1.0.3-py3-none-any.whl.metadata (918 bytes)
# Collecting rfc3987 (from funowl>=0.2.0->oaklib==0.6.4->cas-tools)
#   Using cached rfc3987-1.3.8-py2.py3-none-any.whl.metadata (7.5 kB)
# Collecting more-itertools>=8.5.0 (from inflect>=6.0.0->schema-automator==0.5.1->cas-tools)
#   Using cached more_itertools-10.3.0-py3-none-any.whl.metadata (36 kB)
# Collecting typeguard>=4.0.1 (from inflect>=6.0.0->schema-automator==0.5.1->cas-tools)
#   Using cached typeguard-4.3.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in ./venv/lib/python3.11/site-packages (from jinja2>=3.1.0->linkml==1.7.8->cas-tools) (2.1.5)
# Requirement already satisfied: jsonpointer>=1.9 in ./venv/lib/python3.11/site-packages (from jsonpatch>=1.32->schema-automator==0.5.1->cas-tools) (3.0.0)
# Requirement already satisfied: fqdn in ./venv/lib/python3.11/site-packages (from jsonschema[format]>=4.0.0->linkml==1.7.8->cas-tools) (1.5.1)
# Requirement already satisfied: isoduration in ./venv/lib/python3.11/site-packages (from jsonschema[format]>=4.0.0->linkml==1.7.8->cas-tools) (20.11.0)
# Requirement already satisfied: rfc3339-validator in ./venv/lib/python3.11/site-packages (from jsonschema[format]>=4.0.0->linkml==1.7.8->cas-tools) (0.1.4)
# Requirement already satisfied: uri-template in ./venv/lib/python3.11/site-packages (from jsonschema[format]>=4.0.0->linkml==1.7.8->cas-tools) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in ./venv/lib/python3.11/site-packages (from jsonschema[format]>=4.0.0->linkml==1.7.8->cas-tools) (24.6.0)
# Collecting lark>=1.1.2 (from kgcl-schema<0.7.0,>=0.6.8->oaklib==0.6.4->cas-tools)
#   Using cached lark-1.1.9-py3-none-any.whl.metadata (1.9 kB)
# Collecting deprecated (from linkml-runtime>=1.7.4->linkml==1.7.8->cas-tools)
#   Using cached Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Collecting json-flattener>=0.1.9 (from linkml-runtime>=1.7.4->linkml==1.7.8->cas-tools)
#   Using cached json_flattener-0.1.9-py3-none-any.whl.metadata (5.9 kB)
# Collecting ghp-import>=1.0 (from mkdocs>=1.2.3->schema-automator==0.5.1->cas-tools)
#   Using cached ghp_import-2.1.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting markdown>=3.3.6 (from mkdocs>=1.2.3->schema-automator==0.5.1->cas-tools)
#   Using cached Markdown-3.6-py3-none-any.whl.metadata (7.0 kB)
# Collecting mergedeep>=1.3.4 (from mkdocs>=1.2.3->schema-automator==0.5.1->cas-tools)
#   Using cached mergedeep-1.3.4-py3-none-any.whl.metadata (4.3 kB)
# Collecting mkdocs-get-deps>=0.2.0 (from mkdocs>=1.2.3->schema-automator==0.5.1->cas-tools)
#   Using cached mkdocs_get_deps-0.2.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting pathspec>=0.11.1 (from mkdocs>=1.2.3->schema-automator==0.5.1->cas-tools)
#   Using cached pathspec-0.12.1-py3-none-any.whl.metadata (21 kB)
# Collecting pyyaml-env-tag>=0.1 (from mkdocs>=1.2.3->schema-automator==0.5.1->cas-tools)
#   Using cached pyyaml_env_tag-0.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting ijson (from ndex2<4.0.0,>=3.5.0->oaklib==0.6.4->cas-tools)
#   Using cached ijson-3.3.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (21 kB)
# Collecting requests-toolbelt (from ndex2<4.0.0,>=3.5.0->oaklib==0.6.4->cas-tools)
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting more-click (from ols-client>=0.1.1->oaklib==0.6.4->cas-tools)
#   Using cached more_click-0.1.2-py3-none-any.whl.metadata (4.3 kB)
# Collecting multimethod<=1.10.0 (from pandera>=0.12.0->schema-automator==0.5.1->cas-tools)
#   Using cached multimethod-1.10-py3-none-any.whl.metadata (8.2 kB)
# Collecting wrapt (from pandera>=0.12.0->schema-automator==0.5.1->cas-tools)
#   Using cached wrapt-1.16.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Collecting pytest-logging<2016.0.0,>=2015.11.4 (from prefixcommons>=0.1.7->linkml==1.7.8->cas-tools)
#   Using cached pytest_logging-2015.11.4-py3-none-any.whl
# Collecting chardet~=5.0 (from pronto>=2.5.0->oaklib==0.6.4->cas-tools)
#   Using cached chardet-5.2.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting fastobo~=0.12.2 (from pronto>=2.5.0->oaklib==0.6.4->cas-tools)
#   Using cached fastobo-0.12.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.3 kB)
# Collecting annotated-types>=0.4.0 (from pydantic<3.0.0,>=1.0.0->linkml==1.7.8->cas-tools)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.20.1 (from pydantic<3.0.0,>=1.0.0->linkml==1.7.8->cas-tools)
#   Using cached pydantic_core-2.20.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Collecting cfgraph>=0.2.1 (from pyshex>=0.7.20->linkml==1.7.8->cas-tools)
#   Using cached CFGraph-0.2.1-py3-none-any.whl
# Collecting shexjsg>=0.8.2 (from pyshex>=0.7.20->linkml==1.7.8->cas-tools)
#   Using cached ShExJSG-0.8.2-py2.py3-none-any.whl.metadata (997 bytes)
# Collecting sparqlslurper>=0.5.1 (from pyshex>=0.7.20->linkml==1.7.8->cas-tools)
#   Using cached sparqlslurper-0.5.1-py3-none-any.whl.metadata (430 bytes)
# Collecting tqdm (from pystow>=0.5.0->oaklib==0.6.4->cas-tools)
#   Using cached tqdm-4.66.4-py3-none-any.whl.metadata (57 kB)
# Collecting num2words (from quantulum3>=0.7.9->schema-automator==0.5.1->cas-tools)
#   Using cached num2words-0.5.13-py3-none-any.whl.metadata (12 kB)
# Collecting cattrs>=22.2 (from requests-cache<2.0.0,>=1.0.1->oaklib==0.6.4->cas-tools)
#   Using cached cattrs-23.2.3-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: platformdirs>=2.5 in ./venv/lib/python3.11/site-packages (from requests-cache<2.0.0,>=1.0.1->oaklib==0.6.4->cas-tools) (4.2.2)
# Collecting url-normalize>=1.4 (from requests-cache<2.0.0,>=1.0.1->oaklib==0.6.4->cas-tools)
#   Using cached url_normalize-1.4.3-py2.py3-none-any.whl.metadata (3.1 kB)
# Collecting aiobotocore<3.0.0,>=2.5.4 (from s3fs>=2021.06.1->cellxgene-census==1.10.2->cas-tools)
#   Using cached aiobotocore-2.13.1-py3-none-any.whl.metadata (22 kB)
# Collecting fsspec==2024.6.1.* (from s3fs>=2021.06.1->cellxgene-census==1.10.2->cas-tools)
#   Using cached fsspec-2024.6.1-py3-none-any.whl.metadata (11 kB)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from s3fs>=2021.06.1->cellxgene-census==1.10.2->cas-tools)
#   Using cached aiohttp-3.9.5-cp311-cp311-macosx_11_0_arm64.whl.metadata (7.5 kB)
# Collecting bioregistry>0.5.0 (from schemasheets>=0.1.24->schema-automator==0.5.1->cas-tools)
#   Using cached bioregistry-0.11.10-py3-none-any.whl.metadata (33 kB)
# Collecting ontodev-cogs<0.4.0,>=0.3.3 (from schemasheets>=0.1.24->schema-automator==0.5.1->cas-tools)
#   Using cached ontodev_cogs-0.3.3-py3-none-any.whl.metadata (24 kB)
# Collecting SQLAlchemy-Utils<0.39.0,>=0.38.2 (from semsql>=0.3.1->oaklib==0.6.4->cas-tools)
#   Using cached SQLAlchemy_Utils-0.38.3-py3-none-any.whl.metadata (4.2 kB)
# Collecting deprecation<3.0.0,>=2.1.0 (from sssom<0.5.0,>=0.4.4->oaklib==0.6.4->cas-tools)
#   Using cached deprecation-2.1.0-py2.py3-none-any.whl.metadata (4.6 kB)
# Collecting importlib-resources<7.0.0,>=6.1.1 (from sssom<0.5.0,>=0.4.4->oaklib==0.6.4->cas-tools)
#   Using cached importlib_resources-6.4.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting pansql>=0.0.1 (from pansql[pansql]>=0.0.1->sssom<0.5.0,>=0.4.4->oaklib==0.6.4->cas-tools)
#   Using cached pansql-0.0.1-py3-none-any.whl.metadata (3.6 kB)
# Collecting sssom-schema<0.16.0,>=0.15.2 (from sssom<0.5.0,>=0.4.4->oaklib==0.6.4->cas-tools)
#   Using cached sssom_schema-0.15.2-py3-none-any.whl.metadata (7.7 kB)
# Collecting validators>=0.20.0 (from sssom<0.5.0,>=0.4.4->oaklib==0.6.4->cas-tools)
#   Downloading validators-0.33.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting numba>=0.58.0 (from tiledbsoma~=1.7.0->cellxgene-census==1.10.2->cas-tools)
#   Using cached numba-0.60.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.7 kB)
# Collecting pyarrow-hotfix (from tiledbsoma~=1.7.0->cellxgene-census==1.10.2->cas-tools)
#   Using cached pyarrow_hotfix-0.6-py3-none-any.whl.metadata (3.6 kB)
# Collecting scanpy>=1.9.2 (from tiledbsoma~=1.7.0->cellxgene-census==1.10.2->cas-tools)
#   Using cached scanpy-1.10.2-py3-none-any.whl.metadata (9.3 kB)
# Collecting somacore==1.0.8 (from tiledbsoma~=1.7.0->cellxgene-census==1.10.2->cas-tools)
#   Using cached somacore-1.0.8-py3-none-any.whl.metadata (1.5 kB)
# Collecting tiledb~=0.25.0 (from tiledbsoma~=1.7.0->cellxgene-census==1.10.2->cas-tools)
#   Using cached tiledb-0.25.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (3.6 kB)
# Collecting pyarrow<13.0.0,>=9.0.0 (from tiledbsoma~=1.7.0->cellxgene-census==1.10.2->cas-tools)
#   Using cached pyarrow-12.0.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (3.0 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json==0.6.4->cas-tools)
#   Using cached mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting jsonpath-ng (from linkml-dataops->linkml==1.7.8->cas-tools)
#   Using cached jsonpath_ng-1.6.1-py3-none-any.whl.metadata (18 kB)
# Collecting botocore<1.34.132,>=1.34.70 (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2021.06.1->cellxgene-census==1.10.2->cas-tools)
#   Using cached botocore-1.34.131-py3-none-any.whl.metadata (5.7 kB)
# Collecting aioitertools<1.0.0,>=0.5.1 (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2021.06.1->cellxgene-census==1.10.2->cas-tools)
#   Using cached aioitertools-0.11.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2021.06.1->cellxgene-census==1.10.2->cas-tools)
#   Using cached aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2021.06.1->cellxgene-census==1.10.2->cas-tools)
#   Using cached frozenlist-1.4.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (12 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2021.06.1->cellxgene-census==1.10.2->cas-tools)
#   Using cached multidict-6.0.5-cp311-cp311-macosx_11_0_arm64.whl.metadata (4.2 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2021.06.1->cellxgene-census==1.10.2->cas-tools)
#   Using cached yarl-1.9.4-cp311-cp311-macosx_11_0_arm64.whl.metadata (31 kB)
# WARNING: networkx 3.3 does not provide the extra 'networkx'
# Collecting llvmlite<0.44,>=0.43.0dev0 (from numba>=0.58.0->tiledbsoma~=1.7.0->cellxgene-census==1.10.2->cas-tools)
#   Using cached llvmlite-0.43.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (4.8 kB)
# Collecting daff (from ontodev-cogs<0.4.0,>=0.3.3->schemasheets>=0.1.24->schema-automator==0.5.1->cas-tools)
#   Using cached daff-1.3.46-py3-none-any.whl
# Collecting google (from ontodev-cogs<0.4.0,>=0.3.3->schemasheets>=0.1.24->schema-automator==0.5.1->cas-tools)
#   Using cached google-3.0.0-py2.py3-none-any.whl.metadata (627 bytes)
# Collecting google-api-python-client (from ontodev-cogs<0.4.0,>=0.3.3->schemasheets>=0.1.24->schema-automator==0.5.1->cas-tools)
#   Downloading google_api_python_client-2.137.0-py2.py3-none-any.whl.metadata (6.7 kB)
# Collecting gspread (from ontodev-cogs<0.4.0,>=0.3.3->schemasheets>=0.1.24->schema-automator==0.5.1->cas-tools)
#   Using cached gspread-6.1.2-py3-none-any.whl.metadata (11 kB)
# Collecting gspread-formatting (from ontodev-cogs<0.4.0,>=0.3.3->schemasheets>=0.1.24->schema-automator==0.5.1->cas-tools)
#   Using cached gspread_formatting-1.2.0-py2.py3-none-any.whl.metadata (13 kB)
# Collecting tabulate (from ontodev-cogs<0.4.0,>=0.3.3->schemasheets>=0.1.24->schema-automator==0.5.1->cas-tools)
#   Using cached tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Collecting termcolor (from ontodev-cogs<0.4.0,>=0.3.3->schemasheets>=0.1.24->schema-automator==0.5.1->cas-tools)
#   Using cached termcolor-2.4.0-py3-none-any.whl.metadata (6.1 kB)
# WARNING: pansql 0.0.1 does not provide the extra 'pansql'
# Collecting pytest>=2.8.1 (from pytest-logging<2016.0.0,>=2015.11.4->prefixcommons>=0.1.7->linkml==1.7.8->cas-tools)
#   Using cached pytest-8.2.2-py3-none-any.whl.metadata (7.6 kB)
# Collecting joblib (from scanpy>=1.9.2->tiledbsoma~=1.7.0->cellxgene-census==1.10.2->cas-tools)
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting legacy-api-wrap>=1.4 (from scanpy>=1.9.2->tiledbsoma~=1.7.0->cellxgene-census==1.10.2->cas-tools)
#   Using cached legacy_api_wrap-1.4-py3-none-any.whl.metadata (1.8 kB)
# Collecting matplotlib>=3.6 (from scanpy>=1.9.2->tiledbsoma~=1.7.0->cellxgene-census==1.10.2->cas-tools)
#   Using cached matplotlib-3.9.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (11 kB)
# Collecting patsy (from scanpy>=1.9.2->tiledbsoma~=1.7.0->cellxgene-census==1.10.2->cas-tools)
#   Using cached patsy-0.5.6-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting pynndescent>=0.5 (from scanpy>=1.9.2->tiledbsoma~=1.7.0->cellxgene-census==1.10.2->cas-tools)
#   Using cached pynndescent-0.5.13-py3-none-any.whl.metadata (6.8 kB)
# Collecting scikit-learn>=0.24 (from scanpy>=1.9.2->tiledbsoma~=1.7.0->cellxgene-census==1.10.2->cas-tools)
#   Using cached scikit_learn-1.5.1-cp311-cp311-macosx_12_0_arm64.whl.metadata (12 kB)
# Collecting seaborn>=0.13 (from scanpy>=1.9.2->tiledbsoma~=1.7.0->cellxgene-census==1.10.2->cas-tools)
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting session-info (from scanpy>=1.9.2->tiledbsoma~=1.7.0->cellxgene-census==1.10.2->cas-tools)
#   Using cached session_info-1.0.0-py3-none-any.whl
# Collecting statsmodels>=0.13 (from scanpy>=1.9.2->tiledbsoma~=1.7.0->cellxgene-census==1.10.2->cas-tools)
#   Using cached statsmodels-0.14.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (9.2 kB)
# Collecting umap-learn!=0.5.0,>=0.5 (from scanpy>=1.9.2->tiledbsoma~=1.7.0->cellxgene-census==1.10.2->cas-tools)
#   Using cached umap_learn-0.5.6-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: arrow>=0.15.0 in ./venv/lib/python3.11/site-packages (from isoduration->jsonschema[format]>=4.0.0->linkml==1.7.8->cas-tools) (1.3.0)
# Collecting ply (from jsonpath-ng->linkml-dataops->linkml==1.7.8->cas-tools)
#   Using cached ply-3.11-py2.py3-none-any.whl.metadata (844 bytes)
# Collecting docopt>=0.6.2 (from num2words->quantulum3>=0.7.9->schema-automator==0.5.1->cas-tools)
#   Using cached docopt-0.6.2-py2.py3-none-any.whl
# Collecting sortedcontainers (from pytrie->curies>=0.6.6->oaklib==0.6.4->cas-tools)
#   Using cached sortedcontainers-2.4.0-py2.py3-none-any.whl.metadata (10 kB)
# Collecting rdflib-jsonld==0.6.1 (from rdflib-shim->funowl>=0.2.0->oaklib==0.6.4->cas-tools)
#   Using cached rdflib_jsonld-0.6.1-py2.py3-none-any.whl.metadata (3.4 kB)
# WARNING: scipy 1.14.0 does not provide the extra 'scipy'
# Requirement already satisfied: types-python-dateutil>=2.8.10 in ./venv/lib/python3.11/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format]>=4.0.0->linkml==1.7.8->cas-tools) (2.9.0.20240316)
# Collecting jmespath<2.0.0,>=0.7.1 (from botocore<1.34.132,>=1.34.70->aiobotocore<3.0.0,>=2.5.4->s3fs>=2021.06.1->cellxgene-census==1.10.2->cas-tools)
#   Using cached jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting contourpy>=1.0.1 (from matplotlib>=3.6->scanpy>=1.9.2->tiledbsoma~=1.7.0->cellxgene-census==1.10.2->cas-tools)
#   Using cached contourpy-1.2.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib>=3.6->scanpy>=1.9.2->tiledbsoma~=1.7.0->cellxgene-census==1.10.2->cas-tools)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib>=3.6->scanpy>=1.9.2->tiledbsoma~=1.7.0->cellxgene-census==1.10.2->cas-tools)
#   Using cached fonttools-4.53.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (162 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib>=3.6->scanpy>=1.9.2->tiledbsoma~=1.7.0->cellxgene-census==1.10.2->cas-tools)
#   Using cached kiwisolver-1.4.5-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.4 kB)
# Collecting pillow>=8 (from matplotlib>=3.6->scanpy>=1.9.2->tiledbsoma~=1.7.0->cellxgene-census==1.10.2->cas-tools)
#   Using cached pillow-10.4.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (9.2 kB)
# Collecting iniconfig (from pytest>=2.8.1->pytest-logging<2016.0.0,>=2015.11.4->prefixcommons>=0.1.7->linkml==1.7.8->cas-tools)
#   Using cached iniconfig-2.0.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting pluggy<2.0,>=1.5 (from pytest>=2.8.1->pytest-logging<2016.0.0,>=2015.11.4->prefixcommons>=0.1.7->linkml==1.7.8->cas-tools)
#   Using cached pluggy-1.5.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn>=0.24->scanpy>=1.9.2->tiledbsoma~=1.7.0->cellxgene-census==1.10.2->cas-tools)
#   Using cached threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: beautifulsoup4 in ./venv/lib/python3.11/site-packages (from google->ontodev-cogs<0.4.0,>=0.3.3->schemasheets>=0.1.24->schema-automator==0.5.1->cas-tools) (4.12.3)
# Collecting httplib2<1.dev0,>=0.19.0 (from google-api-python-client->ontodev-cogs<0.4.0,>=0.3.3->schemasheets>=0.1.24->schema-automator==0.5.1->cas-tools)
#   Using cached httplib2-0.22.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0 (from google-api-python-client->ontodev-cogs<0.4.0,>=0.3.3->schemasheets>=0.1.24->schema-automator==0.5.1->cas-tools)
#   Using cached google_auth-2.32.0-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting google-auth-httplib2<1.0.0,>=0.2.0 (from google-api-python-client->ontodev-cogs<0.4.0,>=0.3.3->schemasheets>=0.1.24->schema-automator==0.5.1->cas-tools)
#   Using cached google_auth_httplib2-0.2.0-py2.py3-none-any.whl.metadata (2.2 kB)
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 (from google-api-python-client->ontodev-cogs<0.4.0,>=0.3.3->schemasheets>=0.1.24->schema-automator==0.5.1->cas-tools)
#   Using cached google_api_core-2.19.1-py3-none-any.whl.metadata (2.7 kB)
# Collecting uritemplate<5,>=3.0.1 (from google-api-python-client->ontodev-cogs<0.4.0,>=0.3.3->schemasheets>=0.1.24->schema-automator==0.5.1->cas-tools)
#   Using cached uritemplate-4.1.1-py2.py3-none-any.whl.metadata (2.9 kB)
# Collecting google-auth-oauthlib>=0.4.1 (from gspread->ontodev-cogs<0.4.0,>=0.3.3->schemasheets>=0.1.24->schema-automator==0.5.1->cas-tools)
#   Using cached google_auth_oauthlib-1.2.1-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting stdlib-list (from session-info->scanpy>=1.9.2->tiledbsoma~=1.7.0->cellxgene-census==1.10.2->cas-tools)
#   Using cached stdlib_list-0.10.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting googleapis-common-protos<2.0.dev0,>=1.56.2 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client->ontodev-cogs<0.4.0,>=0.3.3->schemasheets>=0.1.24->schema-automator==0.5.1->cas-tools)
#   Using cached googleapis_common_protos-1.63.2-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.19.5 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client->ontodev-cogs<0.4.0,>=0.3.3->schemasheets>=0.1.24->schema-automator==0.5.1->cas-tools)
#   Using cached protobuf-5.27.2-cp38-abi3-macosx_10_9_universal2.whl.metadata (592 bytes)
# Collecting proto-plus<2.0.0dev,>=1.22.3 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client->ontodev-cogs<0.4.0,>=0.3.3->schemasheets>=0.1.24->schema-automator==0.5.1->cas-tools)
#   Using cached proto_plus-1.24.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client->ontodev-cogs<0.4.0,>=0.3.3->schemasheets>=0.1.24->schema-automator==0.5.1->cas-tools)
#   Downloading cachetools-5.4.0-py3-none-any.whl.metadata (5.3 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client->ontodev-cogs<0.4.0,>=0.3.3->schemasheets>=0.1.24->schema-automator==0.5.1->cas-tools)
#   Using cached pyasn1_modules-0.4.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client->ontodev-cogs<0.4.0,>=0.3.3->schemasheets>=0.1.24->schema-automator==0.5.1->cas-tools)
#   Using cached rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib>=0.4.1->gspread->ontodev-cogs<0.4.0,>=0.3.3->schemasheets>=0.1.24->schema-automator==0.5.1->cas-tools)
#   Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: soupsieve>1.2 in ./venv/lib/python3.11/site-packages (from beautifulsoup4->google->ontodev-cogs<0.4.0,>=0.3.3->schemasheets>=0.1.24->schema-automator==0.5.1->cas-tools) (2.5)
# Collecting pyasn1<0.7.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client->ontodev-cogs<0.4.0,>=0.3.3->schemasheets>=0.1.24->schema-automator==0.5.1->cas-tools)
#   Using cached pyasn1-0.6.0-py2.py3-none-any.whl.metadata (8.3 kB)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread->ontodev-cogs<0.4.0,>=0.3.3->schemasheets>=0.1.24->schema-automator==0.5.1->cas-tools)
#   Using cached oauthlib-3.2.2-py3-none-any.whl.metadata (7.5 kB)
# Downloading cas_tools-1.0.5-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.9/57.9 kB 3.1 MB/s eta 0:00:00
# Downloading anndata-0.10.5-py3-none-any.whl (120 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.9/120.9 kB 5.0 MB/s eta 0:00:00
# Downloading cell_annotation_schema-1.0.0-py3-none-any.whl (25 kB)
# Using cached cellxgene_census-1.10.2-py3-none-any.whl (43 kB)
# Using cached dataclasses_json-0.6.4-py3-none-any.whl (28 kB)
# Using cached deepmerge-1.1.0-py3-none-any.whl (8.5 kB)
# Using cached h5py-3.10.0-cp311-cp311-macosx_11_0_arm64.whl (2.6 MB)
# Using cached jsonschema-4.4.0-py3-none-any.whl (72 kB)
# Using cached linkml-1.7.8-py3-none-any.whl (284 kB)
# Using cached marshmallow-3.21.1-py3-none-any.whl (49 kB)
# Using cached numpy-1.26.4-cp311-cp311-macosx_11_0_arm64.whl (14.0 MB)
# Using cached oaklib-0.6.4-py3-none-any.whl (637 kB)
# Using cached openpyxl-3.1.2-py2.py3-none-any.whl (249 kB)
# Using cached ordered_set-4.1.0-py3-none-any.whl (7.6 kB)
# Using cached pandas-2.2.1-cp311-cp311-macosx_11_0_arm64.whl (11.3 MB)
# Using cached python_dateutil-2.9.0-py2.py3-none-any.whl (230 kB)
# Using cached rdflib-7.0.0-py3-none-any.whl (531 kB)
# Using cached ruamel.yaml-0.18.6-py3-none-any.whl (117 kB)
# Using cached schema_automator-0.5.1-py3-none-any.whl (100 kB)
# Using cached kgcl_rdflib-0.5.0-py3-none-any.whl (34 kB)
# Downloading cap_anndata-0.2.1-py3-none-any.whl (10 kB)
# Downloading urllib3-1.26.19-py2.py3-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.9/143.9 kB 3.8 MB/s eta 0:00:00
# Using cached airium-0.2.6-py3-none-any.whl (13 kB)
# Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Using cached class_resolver-0.4.3-py3-none-any.whl (25 kB)
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Using cached click_default_group-1.2.4-py2.py3-none-any.whl (4.1 kB)
# Using cached click_log-0.4.0-py2.py3-none-any.whl (4.3 kB)
# Using cached curies-0.7.10-py3-none-any.whl (46 kB)
# Using cached duckdb-0.10.3-cp311-cp311-macosx_11_0_arm64.whl (14.2 MB)
# Using cached eutils-0.6.0-py2.py3-none-any.whl (41 kB)
# Using cached funowl-0.2.3-py3-none-any.whl (51 kB)
# Using cached graphviz-0.20.3-py3-none-any.whl (47 kB)
# Using cached inflect-7.3.1-py3-none-any.whl (34 kB)
# Using cached isodate-0.6.1-py2.py3-none-any.whl (41 kB)
# Using cached jsonasobj2-1.0.4-py3-none-any.whl (6.3 kB)
# Using cached jsonlines-4.0.0-py3-none-any.whl (8.7 kB)
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Using cached kgcl_schema-0.6.8-py3-none-any.whl (46 kB)
# Using cached linkml_renderer-0.3.1-py3-none-any.whl (25 kB)
# Using cached linkml_runtime-1.8.0-py3-none-any.whl (575 kB)
# Using cached mkdocs-1.6.0-py3-none-any.whl (3.9 MB)
# Using cached ndex2-3.9.0-py2.py3-none-any.whl (76 kB)
# Using cached networkx-3.3-py3-none-any.whl (1.7 MB)
# Using cached ols_client-0.1.4-py3-none-any.whl (10 kB)
# Using cached ontoportal_client-0.0.4-py3-none-any.whl (8.8 kB)
# Downloading pandera-0.20.3-py3-none-any.whl (255 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 255.6/255.6 kB 9.0 MB/s eta 0:00:00
# Using cached prefixcommons-0.1.12-py3-none-any.whl (29 kB)
# Using cached prefixmaps-0.2.4-py3-none-any.whl (746 kB)
# Using cached pronto-2.5.7-py2.py3-none-any.whl (61 kB)
# Using cached psycopg2_binary-2.9.9-cp311-cp311-macosx_11_0_arm64.whl (2.6 MB)
# Using cached pydantic-2.8.2-py3-none-any.whl (423 kB)
# Using cached pydantic_core-2.20.1-cp311-cp311-macosx_11_0_arm64.whl (1.8 MB)
# Using cached PyJSG-0.11.10-py3-none-any.whl (80 kB)
# Using cached pyparsing-3.1.2-py3-none-any.whl (103 kB)
# Using cached pyrsistent-0.20.0-cp311-cp311-macosx_10_9_universal2.whl (83 kB)
# Using cached PyShEx-0.8.1-py3-none-any.whl (51 kB)
# Using cached PyShExC-0.9.1-py2.py3-none-any.whl (69 kB)
# Using cached pystow-0.5.4-py3-none-any.whl (32 kB)
# Using cached quantulum3-0.9.2-py3-none-any.whl (10.6 MB)
# Using cached requests_cache-1.2.1-py3-none-any.whl (61 kB)
# Using cached ruamel.yaml.clib-0.2.8-cp311-cp311-macosx_13_0_arm64.whl (134 kB)
# Using cached s3fs-2024.6.1-py3-none-any.whl (29 kB)
# Using cached fsspec-2024.6.1-py3-none-any.whl (177 kB)
# Using cached schemasheets-0.2.1-py3-none-any.whl (33 kB)
# Using cached scipy-1.14.0-cp311-cp311-macosx_14_0_arm64.whl (23.1 MB)
# Using cached semsql-0.3.3-py3-none-any.whl (132 kB)
# Using cached SPARQLWrapper-2.0.0-py3-none-any.whl (28 kB)
# Using cached SQLAlchemy-2.0.31-cp311-cp311-macosx_11_0_arm64.whl (2.1 MB)
# Using cached sssom-0.4.11-py3-none-any.whl (167 kB)
# Using cached strsimpy-0.2.1-py3-none-any.whl (45 kB)
# Using cached tenacity-8.5.0-py3-none-any.whl (28 kB)
# Using cached tiledbsoma-1.7.3-cp311-cp311-macosx_11_0_arm64.whl (21.2 MB)
# Using cached somacore-1.0.8-py3-none-any.whl (35 kB)
# Downloading tomlkit-0.13.0-py3-none-any.whl (37 kB)
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Using cached watchdog-4.0.1-cp311-cp311-macosx_11_0_arm64.whl (92 kB)
# Using cached xmltodict-0.13.0-py2.py3-none-any.whl (10.0 kB)
# Using cached array_api_compat-1.7.1-py3-none-any.whl (37 kB)
# Using cached et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Using cached hbreader-0.9.1-py3-none-any.whl (7.6 kB)
# Using cached linkml_dataops-0.1.0-py3-none-any.whl (27 kB)
# Using cached natsort-8.4.0-py3-none-any.whl (38 kB)
# Using cached parse-1.20.2-py2.py3-none-any.whl (20 kB)
# Using cached aiobotocore-2.13.1-py3-none-any.whl (76 kB)
# Using cached aiohttp-3.9.5-cp311-cp311-macosx_11_0_arm64.whl (390 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached bioregistry-0.11.10-py3-none-any.whl (5.2 MB)
# Using cached cattrs-23.2.3-py3-none-any.whl (57 kB)
# Using cached chardet-5.2.0-py3-none-any.whl (199 kB)
# Using cached deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Using cached fastobo-0.12.3-cp311-cp311-macosx_11_0_arm64.whl (1.7 MB)
# Using cached ghp_import-2.1.0-py3-none-any.whl (11 kB)
# Using cached importlib_resources-6.4.0-py3-none-any.whl (38 kB)
# Using cached json_flattener-0.1.9-py3-none-any.whl (10 kB)
# Using cached jsonasobj-1.3.1-py3-none-any.whl (4.4 kB)
# Using cached lark-1.1.9-py3-none-any.whl (111 kB)
# Using cached Markdown-3.6-py3-none-any.whl (105 kB)
# Using cached mergedeep-1.3.4-py3-none-any.whl (6.4 kB)
# Using cached mkdocs_get_deps-0.2.0-py3-none-any.whl (9.5 kB)
# Using cached more_click-0.1.2-py3-none-any.whl (6.7 kB)
# Using cached more_itertools-10.3.0-py3-none-any.whl (59 kB)
# Using cached multimethod-1.10-py3-none-any.whl (9.9 kB)
# Using cached mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Using cached numba-0.60.0-cp311-cp311-macosx_11_0_arm64.whl (2.6 MB)
# Using cached ontodev_cogs-0.3.3-py3-none-any.whl (47 kB)
# Using cached pansql-0.0.1-py3-none-any.whl (26 kB)
# Using cached pathspec-0.12.1-py3-none-any.whl (31 kB)
# Using cached pyarrow-12.0.1-cp311-cp311-macosx_11_0_arm64.whl (22.6 MB)
# Using cached pyyaml_env_tag-0.1-py3-none-any.whl (3.9 kB)
# Using cached scanpy-1.10.2-py3-none-any.whl (2.1 MB)
# Using cached ShExJSG-0.8.2-py2.py3-none-any.whl (14 kB)
# Using cached sparqlslurper-0.5.1-py3-none-any.whl (6.6 kB)
# Using cached SQLAlchemy_Utils-0.38.3-py3-none-any.whl (100 kB)
# Using cached sssom_schema-0.15.2-py3-none-any.whl (28 kB)
# Using cached tiledb-0.25.1-cp311-cp311-macosx_11_0_arm64.whl (10.4 MB)
# Using cached typeguard-4.3.0-py3-none-any.whl (35 kB)
# Using cached url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Downloading validators-0.33.0-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 3.4 MB/s eta 0:00:00
# Using cached wrapt-1.16.0-cp311-cp311-macosx_11_0_arm64.whl (38 kB)
# Using cached bcp47-0.1.0-py3-none-any.whl (13 kB)
# Using cached Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Using cached ijson-3.3.0-cp311-cp311-macosx_11_0_arm64.whl (57 kB)
# Using cached jsonpath_ng-1.6.1-py3-none-any.whl (29 kB)
# Using cached lxml-5.2.2-cp311-cp311-macosx_10_9_universal2.whl (8.1 MB)
# Using cached num2words-0.5.13-py3-none-any.whl (143 kB)
# Using cached pyarrow_hotfix-0.6-py3-none-any.whl (7.9 kB)
# Using cached PyTrie-0.4.0-py3-none-any.whl (6.1 kB)
# Using cached rdflib_shim-1.0.3-py3-none-any.whl (5.2 kB)
# Using cached rdflib_jsonld-0.6.1-py2.py3-none-any.whl (16 kB)
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Using cached rfc3987-1.3.8-py2.py3-none-any.whl (13 kB)
# Using cached tqdm-4.66.4-py3-none-any.whl (78 kB)
# Using cached aioitertools-0.11.0-py3-none-any.whl (23 kB)
# Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Using cached botocore-1.34.131-py3-none-any.whl (12.3 MB)
# Using cached frozenlist-1.4.1-cp311-cp311-macosx_11_0_arm64.whl (53 kB)
# Using cached legacy_api_wrap-1.4-py3-none-any.whl (15 kB)
# Using cached llvmlite-0.43.0-cp311-cp311-macosx_11_0_arm64.whl (28.8 MB)
# Using cached matplotlib-3.9.1-cp311-cp311-macosx_11_0_arm64.whl (7.8 MB)
# Using cached multidict-6.0.5-cp311-cp311-macosx_11_0_arm64.whl (30 kB)
# Using cached pynndescent-0.5.13-py3-none-any.whl (56 kB)
# Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Using cached pytest-8.2.2-py3-none-any.whl (339 kB)
# Using cached scikit_learn-1.5.1-cp311-cp311-macosx_12_0_arm64.whl (11.0 MB)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Using cached statsmodels-0.14.2-cp311-cp311-macosx_11_0_arm64.whl (10.1 MB)
# Using cached patsy-0.5.6-py2.py3-none-any.whl (233 kB)
# Using cached umap_learn-0.5.6-py3-none-any.whl (85 kB)
# Using cached yarl-1.9.4-cp311-cp311-macosx_11_0_arm64.whl (81 kB)
# Using cached google-3.0.0-py2.py3-none-any.whl (45 kB)
# Downloading google_api_python_client-2.137.0-py2.py3-none-any.whl (12.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 14.3 MB/s eta 0:00:00m eta 0:00:010:0101
# Using cached gspread-6.1.2-py3-none-any.whl (57 kB)
# Using cached gspread_formatting-1.2.0-py2.py3-none-any.whl (22 kB)
# Using cached ply-3.11-py2.py3-none-any.whl (49 kB)
# Using cached sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# Using cached termcolor-2.4.0-py3-none-any.whl (7.7 kB)
# Using cached contourpy-1.2.1-cp311-cp311-macosx_11_0_arm64.whl (245 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.53.1-cp311-cp311-macosx_11_0_arm64.whl (2.2 MB)
# Using cached google_api_core-2.19.1-py3-none-any.whl (139 kB)
# Using cached google_auth-2.32.0-py2.py3-none-any.whl (195 kB)
# Using cached google_auth_httplib2-0.2.0-py2.py3-none-any.whl (9.3 kB)
# Using cached google_auth_oauthlib-1.2.1-py2.py3-none-any.whl (24 kB)
# Using cached httplib2-0.22.0-py3-none-any.whl (96 kB)
# Using cached jmespath-1.0.1-py3-none-any.whl (20 kB)
# Using cached kiwisolver-1.4.5-cp311-cp311-macosx_11_0_arm64.whl (66 kB)
# Using cached pillow-10.4.0-cp311-cp311-macosx_11_0_arm64.whl (3.4 MB)
# Using cached pluggy-1.5.0-py3-none-any.whl (20 kB)
# Using cached threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Using cached uritemplate-4.1.1-py2.py3-none-any.whl (10 kB)
# Using cached iniconfig-2.0.0-py3-none-any.whl (5.9 kB)
# Using cached stdlib_list-0.10.0-py3-none-any.whl (79 kB)
# Downloading cachetools-5.4.0-py3-none-any.whl (9.5 kB)
# Using cached googleapis_common_protos-1.63.2-py2.py3-none-any.whl (220 kB)
# Using cached proto_plus-1.24.0-py3-none-any.whl (50 kB)
# Using cached protobuf-5.27.2-cp38-abi3-macosx_10_9_universal2.whl (412 kB)
# Using cached pyasn1_modules-0.4.0-py3-none-any.whl (181 kB)
# Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Using cached pyasn1-0.6.0-py2.py3-none-any.whl (85 kB)
# Installing collected packages: strsimpy, sortedcontainers, rfc3987, ratelimit, ply, parse, jsonasobj, ijson, docopt, deepmerge, daff, bcp47, array-api-compat, appdirs, antlr4-python3-runtime, airium, xmltodict, wrapt, watchdog, validators, urllib3, url-normalize, uritemplate, typeguard, tqdm, tomlkit, threadpoolctl, termcolor, tenacity, tabulate, stdlib-list, sqlalchemy, ruamel.yaml.clib, pyyaml-env-tag, pytrie, python-dateutil, pyrsistent, pyparsing, pyjsg, pydantic-core, pyasn1, pyarrow-hotfix, psycopg2-binary, protobuf, pluggy, pillow, pathspec, ordered-set, oauthlib, numpy, num2words, networkx, natsort, mypy-extensions, multimethod, multidict, more-itertools, mergedeep, marshmallow, markdown, lxml, llvmlite, legacy-api-wrap, lark, kiwisolver, jsonpath-ng, jsonpatch, jsonlines, joblib, jmespath, isodate, iniconfig, importlib-resources, hbreader, graphviz, fsspec, frozenlist, fonttools, fastobo, et-xmlfile, duckdb, deprecation, cycler, click, class-resolver, chardet, cattrs, cachetools, annotated-types, aioitertools, yarl, typing-inspect, tiledb, SQLAlchemy-Utils, shexjsg, session-info, scipy, ruamel-yaml, rsa, rdflib, pytest, pydantic, pyasn1-modules, pyarrow, proto-plus, pronto, patsy, pandas, openpyxl, numba, more-click, mkdocs-get-deps, jsonschema, jsonasobj2, json-flattener, inflect, httplib2, h5py, googleapis-common-protos, google, ghp-import, deprecated, contourpy, click-log, click-default-group, botocore, aiosignal, statsmodels, SPARQLWrapper, scikit-learn, requests-toolbelt, requests-oauthlib, requests-cache, rdflib-jsonld, quantulum3, pytest-logging, pystow, pysolr, pansql, pandera, mkdocs, matplotlib, google-auth, eutils, dataclasses-json, curies, cfgraph, cell-annotation-schema, anndata, aiohttp, somacore, seaborn, rdflib-shim, pynndescent, prefixmaps, prefixcommons, ontoportal-client, ols-client, ndex2, google-auth-oauthlib, google-auth-httplib2, google-api-core, cap-anndata, bioregistry, aiobotocore, umap-learn, sparqlslurper, s3fs, pyshexc, linkml-runtime, gspread, google-api-python-client, funowl, sssom-schema, semsql, scanpy, pyshex, linkml-renderer, linkml-dataops, kgcl-schema, gspread-formatting, tiledbsoma, sssom, ontodev-cogs, linkml, kgcl-rdflib, schemasheets, oaklib, cellxgene-census, schema-automator, cas-tools
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.2.2
#     Uninstalling urllib3-2.2.2:
#       Successfully uninstalled urllib3-2.2.2
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.9.0.post0
#     Uninstalling python-dateutil-2.9.0.post0:
#       Successfully uninstalled python-dateutil-2.9.0.post0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.0
#     Uninstalling numpy-2.0.0:
#       Successfully uninstalled numpy-2.0.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
#   Attempting uninstall: jsonschema
#     Found existing installation: jsonschema 4.23.0
#     Uninstalling jsonschema-4.23.0:
#       Successfully uninstalled jsonschema-4.23.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jupyter-events 0.10.0 requires jsonschema[format-nongpl]>=4.18.0, but you have jsonschema 4.4.0 which is incompatible.
# jupyterlab-server 2.27.3 requires jsonschema>=4.18.0, but you have jsonschema 4.4.0 which is incompatible.
# Successfully installed SPARQLWrapper-2.0.0 SQLAlchemy-Utils-0.38.3 aiobotocore-2.13.1 aiohttp-3.9.5 aioitertools-0.11.0 aiosignal-1.3.1 airium-0.2.6 anndata-0.10.5 annotated-types-0.7.0 antlr4-python3-runtime-4.9.3 appdirs-1.4.4 array-api-compat-1.7.1 bcp47-0.1.0 bioregistry-0.11.10 botocore-1.34.131 cachetools-5.4.0 cap-anndata-0.2.1 cas-tools-1.0.5 cattrs-23.2.3 cell-annotation-schema-1.0.0 cellxgene-census-1.10.2 cfgraph-0.2.1 chardet-5.2.0 class-resolver-0.4.3 click-8.1.7 click-default-group-1.2.4 click-log-0.4.0 contourpy-1.2.1 curies-0.7.10 cycler-0.12.1 daff-1.3.46 dataclasses-json-0.6.4 deepmerge-1.1.0 deprecated-1.2.14 deprecation-2.1.0 docopt-0.6.2 duckdb-0.10.3 et-xmlfile-1.1.0 eutils-0.6.0 fastobo-0.12.3 fonttools-4.53.1 frozenlist-1.4.1 fsspec-2024.6.1 funowl-0.2.3 ghp-import-2.1.0 google-3.0.0 google-api-core-2.19.1 google-api-python-client-2.137.0 google-auth-2.32.0 google-auth-httplib2-0.2.0 google-auth-oauthlib-1.2.1 googleapis-common-protos-1.63.2 graphviz-0.20.3 gspread-6.1.2 gspread-formatting-1.2.0 h5py-3.10.0 hbreader-0.9.1 httplib2-0.22.0 ijson-3.3.0 importlib-resources-6.4.0 inflect-7.3.1 iniconfig-2.0.0 isodate-0.6.1 jmespath-1.0.1 joblib-1.4.2 json-flattener-0.1.9 jsonasobj-1.3.1 jsonasobj2-1.0.4 jsonlines-4.0.0 jsonpatch-1.33 jsonpath-ng-1.6.1 jsonschema-4.4.0 kgcl-rdflib-0.5.0 kgcl-schema-0.6.8 kiwisolver-1.4.5 lark-1.1.9 legacy-api-wrap-1.4 linkml-1.7.8 linkml-dataops-0.1.0 linkml-renderer-0.3.1 linkml-runtime-1.8.0 llvmlite-0.43.0 lxml-5.2.2 markdown-3.6 marshmallow-3.21.1 matplotlib-3.9.1 mergedeep-1.3.4 mkdocs-1.6.0 mkdocs-get-deps-0.2.0 more-click-0.1.2 more-itertools-10.3.0 multidict-6.0.5 multimethod-1.10 mypy-extensions-1.0.0 natsort-8.4.0 ndex2-3.9.0 networkx-3.3 num2words-0.5.13 numba-0.60.0 numpy-1.26.4 oaklib-0.6.4 oauthlib-3.2.2 ols-client-0.1.4 ontodev-cogs-0.3.3 ontoportal-client-0.0.4 openpyxl-3.1.2 ordered-set-4.1.0 pandas-2.2.1 pandera-0.20.3 pansql-0.0.1 parse-1.20.2 pathspec-0.12.1 patsy-0.5.6 pillow-10.4.0 pluggy-1.5.0 ply-3.11 prefixcommons-0.1.12 prefixmaps-0.2.4 pronto-2.5.7 proto-plus-1.24.0 protobuf-5.27.2 psycopg2-binary-2.9.9 pyarrow-12.0.1 pyarrow-hotfix-0.6 pyasn1-0.6.0 pyasn1-modules-0.4.0 pydantic-2.8.2 pydantic-core-2.20.1 pyjsg-0.11.10 pynndescent-0.5.13 pyparsing-3.1.2 pyrsistent-0.20.0 pyshex-0.8.1 pyshexc-0.9.1 pysolr-3.9.0 pystow-0.5.4 pytest-8.2.2 pytest-logging-2015.11.4 python-dateutil-2.9.0 pytrie-0.4.0 pyyaml-env-tag-0.1 quantulum3-0.9.2 ratelimit-2.2.1 rdflib-7.0.0 rdflib-jsonld-0.6.1 rdflib-shim-1.0.3 requests-cache-1.2.1 requests-oauthlib-2.0.0 requests-toolbelt-1.0.0 rfc3987-1.3.8 rsa-4.9 ruamel-yaml-0.18.6 ruamel.yaml.clib-0.2.8 s3fs-2024.6.1 scanpy-1.10.2 schema-automator-0.5.1 schemasheets-0.2.1 scikit-learn-1.5.1 scipy-1.14.0 seaborn-0.13.2 semsql-0.3.3 session-info-1.0.0 shexjsg-0.8.2 somacore-1.0.8 sortedcontainers-2.4.0 sparqlslurper-0.5.1 sqlalchemy-2.0.31 sssom-0.4.11 sssom-schema-0.15.2 statsmodels-0.14.2 stdlib-list-0.10.0 strsimpy-0.2.1 tabulate-0.9.0 tenacity-8.5.0 termcolor-2.4.0 threadpoolctl-3.5.0 tiledb-0.25.1 tiledbsoma-1.7.3 tomlkit-0.13.0 tqdm-4.66.4 typeguard-4.3.0 typing-inspect-0.9.0 umap-learn-0.5.6 uritemplate-4.1.1 url-normalize-1.4.3 urllib3-1.26.19 validators-0.33.0 watchdog-4.0.1 wrapt-1.16.0 xmltodict-0.13.0 yarl-1.9.4
#
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
import os
import ssl
import json
import pandas
import urllib.request as request

from cas.abc_cas_converter import abc2cas
from cas.file_utils import read_json_file

# %%
# SSL: CERTIFICATE_VERIFY_FAILED error workaround
ssl._create_default_https_context = ssl._create_unverified_context

# %%
abc2cas("../cluster_annotation_term_set.csv", "../cluster_annotation_term.csv", "WMB_raw.json")

# %%
cas = read_json_file("WMB_raw.json")

# %%
if not os.path.exists(os.path.join(os.getcwd(), "cluster_annotation_term_annotated.csv")):
    # Download
    request.urlretrieve("https://github.com/brain-bican/taxonomy_curation/files/13811392/cluster_annotation_term_annotated.csv")
annotations_df = pandas.read_csv("cluster_annotation_term_annotated.csv")
annotations_df
# Out:
#                           label                name  \
# 0          CS20230722_NEUR_Glut                Glut
# 1            CS20230722_NEUR_NA                 NaN
# 2          CS20230722_NEUR_GABA                GABA
# 3          CS20230722_NEUR_Dopa                Dopa
# 4     CS20230722_NEUR_Glut-GABA           Glut-GABA
# ...                         ...                 ...
# 6900       CS20230722_CLUS_5318        5318 DC NN_1
# 6901       CS20230722_CLUS_5319   5319 B cells NN_1
# 6902       CS20230722_CLUS_5320       5320 ILC NN_2
# 6903       CS20230722_CLUS_5321  5321 NK cells NN_3
# 6904       CS20230722_CLUS_5322   5322 T cells NN_4
#
#      cluster_annotation_term_set_label     parent_term_label  \
# 0                     CCN20230722_NEUR                   NaN
# 1                     CCN20230722_NEUR                   NaN
# 2                     CCN20230722_NEUR                   NaN
# 3                     CCN20230722_NEUR                   NaN
# 4                     CCN20230722_NEUR                   NaN
# ...                                ...                   ...
# 6900                  CCN20230722_CLUS  CS20230722_SUPT_1197
# 6901                  CCN20230722_CLUS  CS20230722_SUPT_1198
# 6902                  CCN20230722_CLUS  CS20230722_SUPT_1199
# 6903                  CCN20230722_CLUS  CS20230722_SUPT_1200
# 6904                  CCN20230722_CLUS  CS20230722_SUPT_1201
#
#      parent_term_set_label  term_set_order  term_order  \
# 0                      NaN               0           0
# 1                      NaN               0           1
# 2                      NaN               0           2
# 3                      NaN               0           3
# 4                      NaN               0           4
# ...                    ...             ...         ...
# 6900      CCN20230722_SUPT               4        5317
# 6901      CCN20230722_SUPT               4        5318
# 6902      CCN20230722_SUPT               4        5319
# 6903      CCN20230722_SUPT               4        5320
# 6904      CCN20230722_SUPT               4        5321
#
#      cluster_annotation_term_set_name color_hex_triplet        Ontology label  \
# 0                    neurotransmitter           #2B93DF  glutamatergic neuron
# 1                    neurotransmitter           #666666                   NaN
# 2                    neurotransmitter           #FF3358      GABAergic neuron
# 3                    neurotransmitter           #fcf04b   dopaminergic neuron
# 4                    neurotransmitter           #0a9964                   NaN
# ...                               ...               ...                   ...
# 6900                          cluster           #3D5766                   NaN
# 6901                          cluster           #A673FF                   NaN
# 6902                          cluster           #3D6659                   NaN
# 6903                          cluster           #5CCCA1                   NaN
# 6904                          cluster           #931799                   NaN
#
#      Ontology ID                         Notes
# 0     CL:0000679                           NaN
# 1            NaN                           NaN
# 2     CL:0000617                           NaN
# 3     CL:0000700                           NaN
# 4            NaN  Consider compound term in CL
# ...          ...                           ...
# 6900         NaN                           NaN
# 6901         NaN                           NaN
# 6902         NaN                           NaN
# 6903         NaN                           NaN
# 6904         NaN                           NaN
#
# [6905 rows x 12 columns]

# %%
cas["annotations"][0]
# Out:
# {'labelset': 'neurotransmitter',
#  'cell_label': 'Glut',
#  'cell_set_accession': 'CCN20230504_NEUR_Glut'}

# %%
for annotation in cas["annotations"]:
    record = annotations_df[annotations_df["label"]==annotation["cell_set_accession"]].iloc[0]
    if not pandas.isna(record["Ontology label"]):
        annotation["cell_ontology_term"] = record["Ontology label"]
        annotation["cell_ontology_term_id"] = record["Ontology ID"]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 2
#       1 for annotation in cas["annotations"]:
# ----> 2     record = annotations_df[annotations_df["label"]==annotation["cell_set_accession"]].iloc[0]
#       3     if not pandas.isna(record["Ontology label"]):
#       4         annotation["cell_ontology_term"] = record["Ontology label"]
#
# File ~/workspaces/workspace1/experimental_notebooks/WMB_taxonomy/20230630/notebook/venv/lib/python3.11/site-packages/pandas/core/indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/workspaces/workspace1/experimental_notebooks/WMB_taxonomy/20230630/notebook/venv/lib/python3.11/site-packages/pandas/core/indexing.py:1752, in _iLocIndexer._getitem_axis(self, key, axis)
#    1749     raise TypeError("Cannot index by location index with a non-integer key")
#    1751 # validate the location
# -> 1752 self._validate_integer(key, axis)
#    1754 return self.obj._ixs(key, axis=axis)
#
# File ~/workspaces/workspace1/experimental_notebooks/WMB_taxonomy/20230630/notebook/venv/lib/python3.11/site-packages/pandas/core/indexing.py:1685, in _iLocIndexer._validate_integer(self, key, axis)
#    1683 len_axis = len(self.obj._get_axis(axis))
#    1684 if key >= len_axis or key < -len_axis:
# -> 1685     raise IndexError("single positional indexer is out-of-bounds")
#
# IndexError: single positional indexer is out-of-bounds

# %% [markdown]
# Add `author_annotation_fields` using https://www.nature.com/articles/s41586-023-06812-z#Sec49 Table 7.
#
# Manually downloaded the excel and saved each sheet as csv.

# %%
supplementary_df = pandas.read_csv("supplementary_cluster_annotation.csv")
supplementary_df
# Out:
#          cl  cluster_id              cluster_id_label  supertype_id  \
# 0     128.0         1.0  0001 CLA-EPd-CTX Car3 Glut_1           1.0
# 1     129.0         2.0  0002 CLA-EPd-CTX Car3 Glut_1           1.0
# 2     130.0         3.0  0003 CLA-EPd-CTX Car3 Glut_1           1.0
# 3     143.0         4.0  0004 CLA-EPd-CTX Car3 Glut_1           1.0
# 4     131.0         5.0  0005 CLA-EPd-CTX Car3 Glut_2           2.0
# ...     ...         ...                           ...           ...
# 5339    NaN         NaN                           NaN           NaN
# 5340    NaN         NaN                           NaN           NaN
# 5341    NaN         NaN                           NaN           NaN
# 5342    NaN         NaN                           NaN           NaN
# 5343    NaN         NaN                           NaN           NaN
#
#               supertype_label            supertype_id_label  subclass_id  \
# 0     CLA-EPd-CTX Car3 Glut_1  0001 CLA-EPd-CTX Car3 Glut_1          1.0
# 1     CLA-EPd-CTX Car3 Glut_1  0001 CLA-EPd-CTX Car3 Glut_1          1.0
# 2     CLA-EPd-CTX Car3 Glut_1  0001 CLA-EPd-CTX Car3 Glut_1          1.0
# 3     CLA-EPd-CTX Car3 Glut_1  0001 CLA-EPd-CTX Car3 Glut_1          1.0
# 4     CLA-EPd-CTX Car3 Glut_2  0002 CLA-EPd-CTX Car3 Glut_2          1.0
# ...                       ...                           ...          ...
# 5339                      NaN                           NaN          NaN
# 5340                      NaN                           NaN          NaN
# 5341                      NaN                           NaN          NaN
# 5342                      NaN                           NaN          NaN
# 5343                      NaN                           NaN          NaN
#
#              subclass_label          subclass_id_label  class_id  ...  \
# 0     CLA-EPd-CTX Car3 Glut  001 CLA-EPd-CTX Car3 Glut       1.0  ...
# 1     CLA-EPd-CTX Car3 Glut  001 CLA-EPd-CTX Car3 Glut       1.0  ...
# 2     CLA-EPd-CTX Car3 Glut  001 CLA-EPd-CTX Car3 Glut       1.0  ...
# 3     CLA-EPd-CTX Car3 Glut  001 CLA-EPd-CTX Car3 Glut       1.0  ...
# 4     CLA-EPd-CTX Car3 Glut  001 CLA-EPd-CTX Car3 Glut       1.0  ...
# ...                     ...                        ...       ...  ...
# 5339                    NaN                        NaN       NaN  ...
# 5340                    NaN                        NaN       NaN  ...
# 5341                    NaN                        NaN       NaN  ...
# 5342                    NaN                        NaN       NaN  ...
# 5343                    NaN                        NaN       NaN  ...
#
#      CTX.subclass_id CTX.subclass_id.1 CTX.neighborhood_id  \
# 0               21.0              Car3                 4.0
# 1               21.0              Car3                 4.0
# 2               21.0              Car3                 4.0
# 3               21.0              Car3                 4.0
# 4               21.0              Car3                 4.0
# ...              ...               ...                 ...
# 5339             NaN               NaN                 NaN
# 5340             NaN               NaN                 NaN
# 5341             NaN               NaN                 NaN
# 5342             NaN               NaN                 NaN
# 5343             NaN               NaN                 NaN
#
#      CTX.neighborhood_label CTX.size   taxonomy_id cell_set_accession.cluster  \
# 0            L4_5_6_IT_Car3   1937.0  CCN202307220       CS20230722_CLUS_0001
# 1            L4_5_6_IT_Car3   1712.0  CCN202307220       CS20230722_CLUS_0002
# 2            L4_5_6_IT_Car3   9576.0  CCN202307220       CS20230722_CLUS_0003
# 3            L4_5_6_IT_Car3   7469.0  CCN202307220       CS20230722_CLUS_0004
# 4            L4_5_6_IT_Car3    360.0  CCN202307220       CS20230722_CLUS_0005
# ...                     ...      ...           ...                        ...
# 5339                    NaN      NaN           NaN                        NaN
# 5340                    NaN      NaN           NaN                        NaN
# 5341                    NaN      NaN           NaN                        NaN
# 5342                    NaN      NaN           NaN                        NaN
# 5343                    NaN      NaN           NaN                        NaN
#
#       cell_set_accession.supertype  cell_set_accession.subclass  \
# 0             CS20230722_SUPT_0001          CS20230722_SUBC_001
# 1             CS20230722_SUPT_0001          CS20230722_SUBC_001
# 2             CS20230722_SUPT_0001          CS20230722_SUBC_001
# 3             CS20230722_SUPT_0001          CS20230722_SUBC_001
# 4             CS20230722_SUPT_0002          CS20230722_SUBC_001
# ...                            ...                          ...
# 5339                           NaN                          NaN
# 5340                           NaN                          NaN
# 5341                           NaN                          NaN
# 5342                           NaN                          NaN
# 5343                           NaN                          NaN
#
#       cell_set_accession.class
# 0           CS20230722_CLAS_01
# 1           CS20230722_CLAS_01
# 2           CS20230722_CLAS_01
# 3           CS20230722_CLAS_01
# 4           CS20230722_CLAS_01
# ...                        ...
# 5339                       NaN
# 5340                       NaN
# 5341                       NaN
# 5342                       NaN
# 5343                       NaN
#
# [5344 rows x 47 columns]

# %%
for annotation in cas["annotations"]:
    if annotation["labelset"] == "cluster":
        record = supplementary_df[supplementary_df["cell_set_accession.cluster"] == annotation["cell_set_accession"]]
        # assing neighborhood(12) to taxonomy_id(43) as author_annotation_fields
        # columns = list(record)[12:43] 
        columns = ["neighborhood", "anatomical_annotation", "merfish.markers.combo", "cluster.TF.markers.combo", "cluster.markers.combo (within subclass)","cluster.markers.combo"]
        data = record.iloc[0]
        author_annotation_fields = dict()
        for column in columns:
            value = None
            if not pandas.isna(data[column]):
                value = data[column]
            author_annotation_fields[column] = value
        annotation["author_annotation_fields"] = author_annotation_fields
        # if not pandas.isna(data["cluster.markers.combo"]):
        #     annotation["marker_gene_evidence"] = [marker.strip() for marker in str(data["cluster.markers.combo"]).split(",")]

# %%
supplementary_df = pandas.read_csv("supplementary_supertype_annotation.csv")
for annotation in cas["annotations"]:
    if annotation["labelset"] == "supertype":
        record = supplementary_df[supplementary_df["cell_set_accession.supertype"] == annotation["cell_set_accession"]]
        columns = ["supertype.markers.combo (within subclass)", "supertype.markers.combo"]
        data = record.iloc[0]
        author_annotation_fields = dict()
        for column in columns:
            value = None
            if not pandas.isna(data[column]):
                value = data[column]
            author_annotation_fields[column] = value
        annotation["author_annotation_fields"] = author_annotation_fields
        # if not pandas.isna(data["supertype.markers.combo"]):
        #     annotation["marker_gene_evidence"] = [marker.strip() for marker in str(data["supertype.markers.combo"]).split(",")]

# %%
supplementary_df = pandas.read_csv("supplementary_subclass_annotation.csv")
for annotation in cas["annotations"]:
    if annotation["labelset"] == "subclass":
        record = supplementary_df[supplementary_df["cell_set_accession.subclass"] == annotation["cell_set_accession"]]
        columns = ["neighborhood", "subclass.tf.markers.combo", "subclass.markers.combo"]
        data = record.iloc[0]
        author_annotation_fields = dict()
        for column in columns:
            value = None
            if not pandas.isna(data[column]):
                value = data[column]
            author_annotation_fields[column] = value
        annotation["author_annotation_fields"] = author_annotation_fields
        # if not pandas.isna(data["subclass.markers.combo"]):
        #     annotation["marker_gene_evidence"] = [marker.strip() for marker in str(data["subclass.markers.combo"]).split(",")]

# %%
supplementary_df = pandas.read_csv("supplementary_class_annotation.csv")
for annotation in cas["annotations"]:
    if annotation["labelset"] == "class":
        record = supplementary_df[supplementary_df["cell_set_accession.class"] == annotation["cell_set_accession"]]
        columns = ["neighborhood"]
        data = record.iloc[0]
        author_annotation_fields = dict()
        for column in columns:
            value = None
            if not pandas.isna(data[column]):
                value = data[column]
            author_annotation_fields[column] = value
        annotation["author_annotation_fields"] = author_annotation_fields

# %% [markdown]
# Fix missing cell_labels

# %%
for annotation in cas["annotations"]:
    if not annotation.get("cell_label"):
        print("Missing label for: " + annotation["cell_set_accession"])
        annotation["cell_label"] = "NA"
cas["author_name"] = "Hongkui Zeng"
cas["orcid"] = "https://orcid.org/0000-0002-9361-5607"
# Out:
# Missing label for: CS20230722_NEUR_NA

# %%
with open("WMB.json", "w") as out_file:
    out_file.write(json.dumps(cas, indent=2))
